# %%
import pandas as pd

# %%
# Gathering the Data
us_data = pd.read_csv("./data/USvideos.csv")

# %%
# Grouping the Views for the titles since they were seperated by dates in each row
# and we want the total views for each title
us_aff = us_data.groupby("title")["views"].sum()

# %%
# Sorting the data in descending order
# and converting it to a DataFrame
sorted_us_agg = us_aff.sort_values(ascending=False)

# %%
# Merging the sorted data with the original data to get a clear dataframe
# with the title and the views and sorting it by views
# The merged data will contain the original data with the views column
merged_us_agg = us_data.merge(sorted_us_agg, on="title", how="left").sort_values(["views_y"], ascending=False)

# %%
# View the data to see the top 10 titles with the most views
merged_us_agg.loc[:, ["title", "category_id", "views_x", "views_y"]].head(10)
# Out:
#                                                    title  category_id  \
# 38345  Childish Gambino - This Is America (Official V...           10
# 38547  Childish Gambino - This Is America (Official V...           10
# 38146  Childish Gambino - This Is America (Official V...           10
# 37333  Childish Gambino - This Is America (Official V...           10
# 37730  Childish Gambino - This Is America (Official V...           10
# 37935  Childish Gambino - This Is America (Official V...           10
# 37531  Childish Gambino - This Is America (Official V...           10
# 36505  Childish Gambino - This Is America (Official V...           10
# 36913  Childish Gambino - This Is America (Official V...           10
# 36301  Childish Gambino - This Is America (Official V...           10
#
#          views_x     views_y
# 38345  220490543  3758488765
# 38547  225211923  3758488765
# 38146  217750076  3758488765
# 37333  196222618  3758488765
# 37730  205643016  3758488765
# 37935  210338856  3758488765
# 37531  200820941  3758488765
# 36505  173478072  3758488765
# 36913  184446490  3758488765
# 36301  167997997  3758488765

# %%
# Copying the merged data to drop the duplciate columns
copy_merged = merged_us_agg.copy()

# %%
# Drop the duplicate rows
copy_merged.drop_duplicates(subset=["title"], inplace=True)

# %%
# Sorting the data by views and getting the top 10 titles.
copy_merged.sort_values(["views_y"], ascending=False).head(10)
# Out:
#           video_id trending_date  \
# 38345  VYOjWnS4cMY      18.01.06
# 31025  ffxKSjUwKdU      18.26.04
# 35550  7C2z4GqqS5E      18.19.05
# 29950  zEf423kYfqk      18.21.04
# 34349  u9Mv98Gr5pY      18.12.05
# 38997  xTlNMmZKwpA      18.05.06
# 36271  ulNswX3If6U      18.22.05
# 35299  vjI4Alon-3Q      18.17.05
# 35929  DkeiKbqa02g      18.20.05
# 5236   FlsCjmMhFmw      17.10.12
#
#                                                    title  \
# 38345  Childish Gambino - This Is America (Official V...
# 31025               Ariana Grande - No Tears Left To Cry
# 35550                BTS (방탄소년단) 'FAKE LOVE' Official MV
# 29950  Becky G, Natti Natasha - Sin Pijama (Official ...
# 34349                      VENOM - Official Trailer (HD)
# 38997  Cardi B, Bad Bunny & J Balvin - I Like It [Off...
# 36271           Selena Gomez - Back To You (Lyric Video)
# 35299                 Maluma - Marinero (Official Video)
# 35929  Calvin Harris, Dua Lipa - One Kiss (Official V...
# 5236   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
#
#                      channel_title  category_id              publish_time  \
# 38345          ChildishGambinoVEVO           10  2018-05-06T04:00:07.000Z
# 31025             ArianaGrandeVevo           10  2018-04-20T04:00:03.000Z
# 35550                      ibighit           10  2018-05-18T09:00:02.000Z
# 29950                   BeckyGVEVO           10  2018-04-20T10:40:51.000Z
# 34349  Sony Pictures Entertainment           24  2018-04-24T03:45:03.000Z
# 38997                      Cardi B           10  2018-05-29T14:05:10.000Z
# 36271                 Selena Gomez            1  2018-05-10T16:00:11.000Z
# 35299                   MalumaVEVO           10  2018-05-04T10:00:33.000Z
# 35929             CalvinHarrisVEVO           10  2018-05-02T23:01:00.000Z
# 5236             YouTube Spotlight           24  2017-12-06T17:58:51.000Z
#
#                                                     tags    views_x    likes  \
# 38345  Childish Gambino|"Rap"|"This Is America"|"mcDJ...  220490543  4962403
# 31025  Ariana|"Grande"|"No"|"Tears"|"Left"|"To"|"Cry"...   51658588  2285218
# 35550          BIGHIT|"빅히트"|"방탄소년단"|"BTS"|"BANGTAN"|"방탄"   39349927  3880071
# 29950  Becky G|"Natti Natasha"|"Natti Natasha Music"|...    6978753   351687
# 34349  Venom|"Venom Movie"|"Venom (2018)"|"Marvel"|"M...   58530197  1289726
# 38997  Cardi B|"I Like It"|"Invasion of Privacy"|"Bad...   48619426  1430773
# 36271  selena gomez|"13 reasons why"|"back to you"|"s...   18638967   652104
# 35299  Maluma Marinero|"Maluma Marinero official vide...   38015626   744382
# 35929  calvin harris|"calvin harris one kiss"|"calvin...   57519404   749382
# 5236   Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...  100911567  2656659
#
#        dislikes  comment_count  \
# 38345    338105         512337
# 31025     82709         197058
# 35550     72707         692305
# 29950     25332          23914
# 34349     46882         139287
# 38997     76260          85799
# 36271     10072          34216
# 35299     51632          41508
# 35929     32820          23946
# 5236    1353647         682890
#
#                                        thumbnail_link  comments_disabled  \
# 38345  https://i.ytimg.com/vi/VYOjWnS4cMY/default.jpg              False
# 31025  https://i.ytimg.com/vi/ffxKSjUwKdU/default.jpg              False
# 35550  https://i.ytimg.com/vi/7C2z4GqqS5E/default.jpg              False
# 29950  https://i.ytimg.com/vi/zEf423kYfqk/default.jpg              False
# 34349  https://i.ytimg.com/vi/u9Mv98Gr5pY/default.jpg              False
# 38997  https://i.ytimg.com/vi/xTlNMmZKwpA/default.jpg              False
# 36271  https://i.ytimg.com/vi/ulNswX3If6U/default.jpg              False
# 35299  https://i.ytimg.com/vi/vjI4Alon-3Q/default.jpg              False
# 35929  https://i.ytimg.com/vi/DkeiKbqa02g/default.jpg              False
# 5236   https://i.ytimg.com/vi/FlsCjmMhFmw/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 38345             False                   False
# 31025             False                   False
# 35550             False                   False
# 29950             False                   False
# 34349             False                   False
# 38997             False                   False
# 36271             False                   False
# 35299             False                   False
# 35929             False                   False
# 5236              False                   False
#
#                                              description     views_y
# 38345  “This is America” by Childish Gambino http://s...  3758488765
# 31025  No Tears Left To Cry (Official Video)\nSong Av...  1529291326
# 35550  BTS (방탄소년단) 'FAKE LOVE' Official MVDirector : ...  1283188291
# 29950  Becky G & Natti Natasha – “Sin Pijama”\n\nNUEV...  1182971286
# 34349  We Are #Venom. 10.5.18One of Marvel's most eni...  1003151226
# 38997  Cardi B, Bad Bunny & J Balvin - I Like It from...   896558471
# 36271  Get 'Back To You,' out now: http://smarturl.it...   818792483
# 35299  Maluma  – “Marinero”¡NUEVO ÁLBUM “F.A.M.E” DIS...   803455479
# 35929  Calvin Harris & Dua Lipa – One Kiss (Official ...   792843004
# 5236   YouTube Rewind 2017. Celebrating the videos, p...   780801040

# %%
# Filtering the data to get onyl required columns
top_10_us_videos = copy_merged.loc[:, ["title", "category_id", "views_x", "views_y"]].head(10)

# %%
# Adding tge region column to the data
top_10_us_videos["region"] = "US"

# %%
# Getting the US category data
us_category_data_raw = pd.read_json("./data/US_category_id.json")

# %%
# Converting the JSON data to a DataFrame
us_category_data = us_category_data_raw["items"].apply(pd.Series)

# %%
# Function to grab the category name from the JSON data
def get_category_name(item):
    return item["snippet"]["title"]

# %%
# Applied the function to get the category name
# and added it to the DataFrame
us_category_data["category_name"] = us_category_data.apply(get_category_name, axis=1)

# %%
# Converting the id field to numeric so the data can be merged
us_category_data["id"] = pd.to_numeric(us_category_data["id"])

# %%
# Merged the top 10 videos with the category data
# to get the category name for each video
us_final_data = pd.merge(
    top_10_us_videos,
    us_category_data,
    left_on="category_id",
    right_on="id",
    how="left",
)

# %%
# This is the final data with the top 10 videos and their category names for USA
us_final_data
